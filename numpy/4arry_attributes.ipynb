# %%
import numpy as np

arr = np.array([[3,3,2],[3,5,1],[9,3,5]])
arr
# Out:
# array([[3, 3, 2],
#        [3, 5, 1],
#        [9, 3, 5]])

# %%
arr.shape
# Out:
# (3, 3)

# %%
arr.size
# Out:
# 9

# %%
arr.dtype
# Out:
# dtype('int64')
