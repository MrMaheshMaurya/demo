# %%
import numpy as np

arr = np.array([[2,4,2],[9,4,2],[5,9,3]])
arr
# Out:
# array([[2, 4, 2],
#        [9, 4, 2],
#        [5, 9, 3]])

# %%
arr.min()
# Out:
# np.int64(2)

# %%
arr.max()
# Out:
# np.int64(9)

# %%
arr.sum()
# Out:
# np.int64(40)

# %%
np.sum(arr,axis=0)  # colluom to zero axis
# Out:
# array([16, 17,  7])

# %%
np.sum(arr,axis=1)    #row to 1 axis
# Out:
# array([ 8, 15, 17])

# %%
arr.mean()
# Out:
# np.float64(4.444444444444445)

# %%
arr.std()
# Out:
# np.float64(2.629368792488718)

# %%
arr.argmax()  #maximum value index
# Out:
# np.int64(3)

# %%
arr.argmin()   #minimum value index
# Out:
# np.int64(0)
